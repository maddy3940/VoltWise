# %%
import requests
import pandas as pd
import datetime
from functools import wraps
import os

# %%
# Decorators
def error_log(function_name):
    def inner_decorator(func):
        @wraps(func)
        def wrapper(*args, **kwargs):
            try:
                result = func(*args, **kwargs)
                return result
            except Exception as e:
                print(f"Function {function_name} encountered an error: {e}")
                
        return wrapper
    return inner_decorator

# %%
# @error_log('fetch_data')
def fetch_data(url):

    # call API
    r = requests.get(url)
    op = r.json()
    
    # json to data frame
    df = pd.json_normalize(op['response']['data'])
    df = df.pivot(columns="type-name", values='value', index = ['period', 'respondent'] )
    
    df.reset_index(inplace=True)
    
    # organize data as needed
    #df.drop(columns=['Day-ahead demand forecast','Total interchange'], inplace=True)
    df[['Date', 'Hour']] = df['period'].str.split('T',expand=True)
    df = df.drop('period', axis = 1)
    df.rename(columns={'respondent':'region'}, inplace=True)
    df = df[['Date','Hour','region','Demand','Net generation','Day-ahead demand forecast','Total interchange']]
    
    # segregate data based on regions
    final_dict = segregate_to_region(df)

    return final_dict

# %%
# @error_log('segregate_to_region')
def segregate_to_region(df):
    data = {}
    for r in regions:
        data[r] = df[df['region']==r].reset_index().drop(columns=['index'])
        if len(data[r])<96:
            temp = data_correction(r,data[r])
            temp.reset_index(inplace=True)
            temp.drop(columns=['index'],inplace=True)
            data[r] = temp
        
    return data

# %%
# @error_log('data_correction')
def data_correction(r,df):
    hour = ['{:02d}'.format(i) for i in range(24)]
    uq_date = df['Date'].unique().tolist()
    dfs=[]
    for dt in uq_date:
        uq_hour = df[df['Date']==dt]['Hour'].unique().tolist()
        missing_hr = [x for x in hour if x not in uq_hour]
        if len(missing_hr)!=0:
            new_df=generate_data(df[(df['Date']==dt)],missing_hr,r,dt)
#             print(r,dt,missing_hr,len(new_df))
            dfs.append(new_df)
        else:
            dfs.append(df[(df['Date']==dt)])
    print('Data Correction')
    print(uq_date)
    dfs = pd.concat(dfs)
#     print(len(dfs))
    return dfs

# %%
# @error_log('generate_data')
def generate_data(df,missing_hr,r,dt):
    
    demand_median = df['Demand'].median()
    net_gen_median = df['Net generation'].median()
    
    forecast_median = df['Day-ahead demand forecast'].median()
    interchange_median = df['Total interchange'].median()
    
    new_data=[]
    for hr in missing_hr:
        new_data.append((dt,hr,r,demand_median,net_gen_median,forecast_median,interchange_median))
        
    df_missing = pd.DataFrame(new_data,columns=['Date', 'Hour', 'region','Demand','Net generation','Day-ahead demand forecast','Total interchange'])
    df_new = pd.concat([df,df_missing])
    df_new = df_new.sort_values(['Date','Hour'])
    
    return df_new

# %%
# @error_log('get_new_dates')
def get_new_dates(start_date,end_date):
    start_date = datetime.datetime.strptime(start_date, '%Y-%m-%d')
    end_date = datetime.datetime.strptime(end_date, '%Y-%m-%d')

    st =  end_date + datetime.timedelta(days=1)
    start_date = st.strftime('%Y-%m-%d')
    end_date = (st + datetime.timedelta(days=3)).strftime('%Y-%m-%d')
    
    return start_date, end_date

# %%
start_date =  "2015-07-01"
end_date = "2015-07-04"
regions = ['CAL', 'CAR', 'CENT', 'FLA', 'MIDA', 'MIDW', 'NE', 'NY', 'SE', 'SW', 'TEX']
region_data_dict={}

# %%
while end_date<='2023-07-10':
    
    url= f"https://api.eia.gov/v2/electricity/rto/region-data/data/?\
frequency=hourly&data[0]=value&facets[respondent][]=CAL\
&facets[respondent][]=CAR&facets[respondent][]=CENT&facets[respondent][]=FLA&facets[respondent][]=MIDA\
&facets[respondent][]=MIDW&facets[respondent][]=NE&facets[respondent][]=NY&facets[respondent][]=SE&\
facets[respondent][]=SW&facets[respondent][]=TEX&\
start={start_date}T00&end={end_date}T23\
&sort[0][column]=period&sort[0][direction]=desc&offset=0&length=5000\
&api_key=2Ztw7IK10RqAv0oag9T2o2FOV8YZgRpapfTEvhwH"
    print(f'Now fetching data from {start_date} to {end_date}')
    temp=fetch_data(url)
    ct=0
    for k in temp.keys():
        if k in region_data_dict.keys():
            region_data_dict[k].append(temp[k])
            ct+=len(temp[k])
        else:
            region_data_dict[k]=[temp[k]]
            ct+=len(temp[k])

    print(f'Got demand data from date {start_date} to {end_date} and its count is {ct}')
    
    start_date,end_date = get_new_dates(start_date,end_date)
# Out:
# Now fetching data from 2015-07-01 to 2015-07-04
# Data Correction
# ['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04']
# Data Correction
# ['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04']
# Data Correction
# ['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04']
# Data Correction
# ['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04']
# Data Correction
# ['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04']
# Data Correction
# ['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04']
# Data Correction
# ['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04']
# Data Correction
# ['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04']
# Data Correction
# ['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04']
# Data Correction
# ['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04']
# Data Correction
# ['2015-07-01', '2015-07-02', '2015-07-03', '2015-07-04']
# Got demand data from date 2015-07-01 to 2015-07-04 and its count is 1056
# Now fetching data from 2015-07-05 to 2015-07-08
# Got demand data from date 2015-07-05 to 2015-07-08 and its count is 1056
# Now fetching data from 2015-07-09 to 2015-07-12
# Got demand data from date 2015-07-09 to 2015-07-12 and its count is 1056
# Now fetching data from 2015-07-13 to 2015-07-16
# Got demand data from date 2015-07-13 to 2015-07-16 and its count is 1056
# Now fetching data from 2015-07-17 to 2015-07-20
# Got demand data from date 2015-07-17 to 2015-07-20 and its count is 1056
# Now fetching data from 2015-07-21 to 2015-07-24
# Got demand data from date 2015-07-21 to 2015-07-24 and its count is 1056
# Now fetching data from 2015-07-25 to 2015-07-28
# Got demand data from date 2015-07-25 to 2015-07-28 and its count is 1056
# Now fetching data from 2015-07-29 to 2015-08-01
# Got demand data from date 2015-07-29 to 2015-08-01 and its count is 1056
# Now fetching data from 2015-08-02 to 2015-08-05
# Got demand data from date 2015-08-02 to 2015-08-05 and its count is 1056
# Now fetching data from 2015-08-06 to 2015-08-09
# Got demand data from date 2015-08-06 to 2015-08-09 and its count is 1056
# Now fetching data from 2015-08-10 to 2015-08-13
# Got demand data from date 2015-08-10 to 2015-08-13 and its count is 1056
# Now fetching data from 2015-08-14 to 2015-08-17
# Got demand data from date 2015-08-14 to 2015-08-17 and its count is 1056
# Now fetching data from 2015-08-18 to 2015-08-21
# Got demand data from date 2015-08-18 to 2015-08-21 and its count is 1056
# Now fetching data from 2015-08-22 to 2015-08-25
# Got demand data from date 2015-08-22 to 2015-08-25 and its count is 1056
# Now fetching data from 2015-08-26 to 2015-08-29
# Got demand data from date 2015-08-26 to 2015-08-29 and its count is 1056
# Now fetching data from 2015-08-30 to 2015-09-02
# Got demand data from date 2015-08-30 to 2015-09-02 and its count is 1056
# Now fetching data from 2015-09-03 to 2015-09-06
# Got demand data from date 2015-09-03 to 2015-09-06 and its count is 1056
# Now fetching data from 2015-09-07 to 2015-09-10
# Got demand data from date 2015-09-07 to 2015-09-10 and its count is 1056
# Now fetching data from 2015-09-11 to 2015-09-14
# Got demand data from date 2015-09-11 to 2015-09-14 and its count is 1056
# Now fetching data from 2015-09-15 to 2015-09-18
# Got demand data from date 2015-09-15 to 2015-09-18 and its count is 1056
# Now fetching data from 2015-09-19 to 2015-09-22
# Got demand data from date 2015-09-19 to 2015-09-22 and its count is 1056
# Now fetching data from 2015-09-23 to 2015-09-26
# Got demand data from date 2015-09-23 to 2015-09-26 and its count is 1056
# Now fetching data from 2015-09-27 to 2015-09-30
# Got demand data from date 2015-09-27 to 2015-09-30 and its count is 1056
# Now fetching data from 2015-10-01 to 2015-10-04
# Got demand data from date 2015-10-01 to 2015-10-04 and its count is 1056
# Now fetching data from 2015-10-05 to 2015-10-08
# Got demand data from date 2015-10-05 to 2015-10-08 and its count is 1056
# Now fetching data from 2015-10-09 to 2015-10-12
# Got demand data from date 2015-10-09 to 2015-10-12 and its count is 1056
# Now fetching data from 2015-10-13 to 2015-10-16
# Got demand data from date 2015-10-13 to 2015-10-16 and its count is 1056
# Now fetching data from 2015-10-17 to 2015-10-20
# Got demand data from date 2015-10-17 to 2015-10-20 and its count is 1056
# Now fetching data from 2015-10-21 to 2015-10-24
# Got demand data from date 2015-10-21 to 2015-10-24 and its count is 1056
# Now fetching data from 2015-10-25 to 2015-10-28
# Got demand data from date 2015-10-25 to 2015-10-28 and its count is 1056
# Now fetching data from 2015-10-29 to 2015-11-01
# Got demand data from date 2015-10-29 to 2015-11-01 and its count is 1056
# Now fetching data from 2015-11-02 to 2015-11-05
# Got demand data from date 2015-11-02 to 2015-11-05 and its count is 1056
# Now fetching data from 2015-11-06 to 2015-11-09
# Got demand data from date 2015-11-06 to 2015-11-09 and its count is 1056
# Now fetching data from 2015-11-10 to 2015-11-13
# Got demand data from date 2015-11-10 to 2015-11-13 and its count is 1056
# Now fetching data from 2015-11-14 to 2015-11-17
# Got demand data from date 2015-11-14 to 2015-11-17 and its count is 1056
# Now fetching data from 2015-11-18 to 2015-11-21
# Got demand data from date 2015-11-18 to 2015-11-21 and its count is 1056
# Now fetching data from 2015-11-22 to 2015-11-25
# Got demand data from date 2015-11-22 to 2015-11-25 and its count is 1056
# Now fetching data from 2015-11-26 to 2015-11-29
# Got demand data from date 2015-11-26 to 2015-11-29 and its count is 1056
# Now fetching data from 2015-11-30 to 2015-12-03
# Got demand data from date 2015-11-30 to 2015-12-03 and its count is 1056
# Now fetching data from 2015-12-04 to 2015-12-07
# Got demand data from date 2015-12-04 to 2015-12-07 and its count is 1056
# Now fetching data from 2015-12-08 to 2015-12-11
# Got demand data from date 2015-12-08 to 2015-12-11 and its count is 1056
# Now fetching data from 2015-12-12 to 2015-12-15
# Got demand data from date 2015-12-12 to 2015-12-15 and its count is 1056
# Now fetching data from 2015-12-16 to 2015-12-19
# Got demand data from date 2015-12-16 to 2015-12-19 and its count is 1056
# Now fetching data from 2015-12-20 to 2015-12-23
# Got demand data from date 2015-12-20 to 2015-12-23 and its count is 1056
# Now fetching data from 2015-12-24 to 2015-12-27
# Got demand data from date 2015-12-24 to 2015-12-27 and its count is 1056
# Now fetching data from 2015-12-28 to 2015-12-31
# Got demand data from date 2015-12-28 to 2015-12-31 and its count is 1056
# Now fetching data from 2016-01-01 to 2016-01-04
# Got demand data from date 2016-01-01 to 2016-01-04 and its count is 1056
# Now fetching data from 2016-01-05 to 2016-01-08
# Got demand data from date 2016-01-05 to 2016-01-08 and its count is 1056
# Now fetching data from 2016-01-09 to 2016-01-12
# Got demand data from date 2016-01-09 to 2016-01-12 and its count is 1056
# Now fetching data from 2016-01-13 to 2016-01-16
# Got demand data from date 2016-01-13 to 2016-01-16 and its count is 1056
# Now fetching data from 2016-01-17 to 2016-01-20
# Got demand data from date 2016-01-17 to 2016-01-20 and its count is 1056
# Now fetching data from 2016-01-21 to 2016-01-24
# Got demand data from date 2016-01-21 to 2016-01-24 and its count is 1056
# Now fetching data from 2016-01-25 to 2016-01-28
# Got demand data from date 2016-01-25 to 2016-01-28 and its count is 1056
# Now fetching data from 2016-01-29 to 2016-02-01
# Got demand data from date 2016-01-29 to 2016-02-01 and its count is 1056
# Now fetching data from 2016-02-02 to 2016-02-05
# Got demand data from date 2016-02-02 to 2016-02-05 and its count is 1056
# Now fetching data from 2016-02-06 to 2016-02-09
# Got demand data from date 2016-02-06 to 2016-02-09 and its count is 1056
# Now fetching data from 2016-02-10 to 2016-02-13
# Got demand data from date 2016-02-10 to 2016-02-13 and its count is 1056
# Now fetching data from 2016-02-14 to 2016-02-17
# Got demand data from date 2016-02-14 to 2016-02-17 and its count is 1056
# Now fetching data from 2016-02-18 to 2016-02-21
# Got demand data from date 2016-02-18 to 2016-02-21 and its count is 1056
# Now fetching data from 2016-02-22 to 2016-02-25
# Got demand data from date 2016-02-22 to 2016-02-25 and its count is 1056
# Now fetching data from 2016-02-26 to 2016-02-29
# Got demand data from date 2016-02-26 to 2016-02-29 and its count is 1056
# Now fetching data from 2016-03-01 to 2016-03-04
# Got demand data from date 2016-03-01 to 2016-03-04 and its count is 1056
# Now fetching data from 2016-03-05 to 2016-03-08
# Got demand data from date 2016-03-05 to 2016-03-08 and its count is 1056
# Now fetching data from 2016-03-09 to 2016-03-12
# Got demand data from date 2016-03-09 to 2016-03-12 and its count is 1056
# Now fetching data from 2016-03-13 to 2016-03-16
# Got demand data from date 2016-03-13 to 2016-03-16 and its count is 1056
# Now fetching data from 2016-03-17 to 2016-03-20
# Got demand data from date 2016-03-17 to 2016-03-20 and its count is 1056
# Now fetching data from 2016-03-21 to 2016-03-24
# Got demand data from date 2016-03-21 to 2016-03-24 and its count is 1056
# Now fetching data from 2016-03-25 to 2016-03-28
# Got demand data from date 2016-03-25 to 2016-03-28 and its count is 1056
# Now fetching data from 2016-03-29 to 2016-04-01
# Got demand data from date 2016-03-29 to 2016-04-01 and its count is 1056
# Now fetching data from 2016-04-02 to 2016-04-05
# Got demand data from date 2016-04-02 to 2016-04-05 and its count is 1056
# Now fetching data from 2016-04-06 to 2016-04-09
# Got demand data from date 2016-04-06 to 2016-04-09 and its count is 1056
# Now fetching data from 2016-04-10 to 2016-04-13
# Got demand data from date 2016-04-10 to 2016-04-13 and its count is 1056
# Now fetching data from 2016-04-14 to 2016-04-17
# Got demand data from date 2016-04-14 to 2016-04-17 and its count is 1056
# Now fetching data from 2016-04-18 to 2016-04-21
# Got demand data from date 2016-04-18 to 2016-04-21 and its count is 1056
# Now fetching data from 2016-04-22 to 2016-04-25
# Got demand data from date 2016-04-22 to 2016-04-25 and its count is 1056
# Now fetching data from 2016-04-26 to 2016-04-29
# Got demand data from date 2016-04-26 to 2016-04-29 and its count is 1056
# Now fetching data from 2016-04-30 to 2016-05-03
# Got demand data from date 2016-04-30 to 2016-05-03 and its count is 1056
# Now fetching data from 2016-05-04 to 2016-05-07
# Got demand data from date 2016-05-04 to 2016-05-07 and its count is 1056
# Now fetching data from 2016-05-08 to 2016-05-11
# Got demand data from date 2016-05-08 to 2016-05-11 and its count is 1056
# Now fetching data from 2016-05-12 to 2016-05-15
# Got demand data from date 2016-05-12 to 2016-05-15 and its count is 1056
# Now fetching data from 2016-05-16 to 2016-05-19
# Got demand data from date 2016-05-16 to 2016-05-19 and its count is 1056
# Now fetching data from 2016-05-20 to 2016-05-23
# Got demand data from date 2016-05-20 to 2016-05-23 and its count is 1056
# Now fetching data from 2016-05-24 to 2016-05-27
# Got demand data from date 2016-05-24 to 2016-05-27 and its count is 1056
# Now fetching data from 2016-05-28 to 2016-05-31
# Got demand data from date 2016-05-28 to 2016-05-31 and its count is 1056
# Now fetching data from 2016-06-01 to 2016-06-04
# Got demand data from date 2016-06-01 to 2016-06-04 and its count is 1056
# Now fetching data from 2016-06-05 to 2016-06-08
# Got demand data from date 2016-06-05 to 2016-06-08 and its count is 1056
# Now fetching data from 2016-06-09 to 2016-06-12
# Got demand data from date 2016-06-09 to 2016-06-12 and its count is 1056
# Now fetching data from 2016-06-13 to 2016-06-16
# Got demand data from date 2016-06-13 to 2016-06-16 and its count is 1056
# Now fetching data from 2016-06-17 to 2016-06-20
# Got demand data from date 2016-06-17 to 2016-06-20 and its count is 1056
# Now fetching data from 2016-06-21 to 2016-06-24
# Got demand data from date 2016-06-21 to 2016-06-24 and its count is 1056
# Now fetching data from 2016-06-25 to 2016-06-28
# Got demand data from date 2016-06-25 to 2016-06-28 and its count is 1056
# Now fetching data from 2016-06-29 to 2016-07-02
# Got demand data from date 2016-06-29 to 2016-07-02 and its count is 1056
# Now fetching data from 2016-07-03 to 2016-07-06
# Got demand data from date 2016-07-03 to 2016-07-06 and its count is 1056
# Now fetching data from 2016-07-07 to 2016-07-10
# Got demand data from date 2016-07-07 to 2016-07-10 and its count is 1056
# Now fetching data from 2016-07-11 to 2016-07-14
# Got demand data from date 2016-07-11 to 2016-07-14 and its count is 1056
# Now fetching data from 2016-07-15 to 2016-07-18
# Got demand data from date 2016-07-15 to 2016-07-18 and its count is 1056
# Now fetching data from 2016-07-19 to 2016-07-22
# Got demand data from date 2016-07-19 to 2016-07-22 and its count is 1056
# Now fetching data from 2016-07-23 to 2016-07-26
# Got demand data from date 2016-07-23 to 2016-07-26 and its count is 1056
# Now fetching data from 2016-07-27 to 2016-07-30
# Got demand data from date 2016-07-27 to 2016-07-30 and its count is 1056
# Now fetching data from 2016-07-31 to 2016-08-03
# Got demand data from date 2016-07-31 to 2016-08-03 and its count is 1056
# Now fetching data from 2016-08-04 to 2016-08-07
# Got demand data from date 2016-08-04 to 2016-08-07 and its count is 1056
# Now fetching data from 2016-08-08 to 2016-08-11
# Got demand data from date 2016-08-08 to 2016-08-11 and its count is 1056
# Now fetching data from 2016-08-12 to 2016-08-15
# Got demand data from date 2016-08-12 to 2016-08-15 and its count is 1056
# Now fetching data from 2016-08-16 to 2016-08-19
# Got demand data from date 2016-08-16 to 2016-08-19 and its count is 1056
# Now fetching data from 2016-08-20 to 2016-08-23
# Got demand data from date 2016-08-20 to 2016-08-23 and its count is 1056
# Now fetching data from 2016-08-24 to 2016-08-27
# Got demand data from date 2016-08-24 to 2016-08-27 and its count is 1056
# Now fetching data from 2016-08-28 to 2016-08-31
# Got demand data from date 2016-08-28 to 2016-08-31 and its count is 1056
# Now fetching data from 2016-09-01 to 2016-09-04
# Got demand data from date 2016-09-01 to 2016-09-04 and its count is 1056
# Now fetching data from 2016-09-05 to 2016-09-08
# Got demand data from date 2016-09-05 to 2016-09-08 and its count is 1056
# Now fetching data from 2016-09-09 to 2016-09-12
# Got demand data from date 2016-09-09 to 2016-09-12 and its count is 1056
# Now fetching data from 2016-09-13 to 2016-09-16
# Got demand data from date 2016-09-13 to 2016-09-16 and its count is 1056
# Now fetching data from 2016-09-17 to 2016-09-20
# Got demand data from date 2016-09-17 to 2016-09-20 and its count is 1056
# Now fetching data from 2016-09-21 to 2016-09-24
# Got demand data from date 2016-09-21 to 2016-09-24 and its count is 1056
# Now fetching data from 2016-09-25 to 2016-09-28
# Got demand data from date 2016-09-25 to 2016-09-28 and its count is 1056
# Now fetching data from 2016-09-29 to 2016-10-02
# Got demand data from date 2016-09-29 to 2016-10-02 and its count is 1056
# Now fetching data from 2016-10-03 to 2016-10-06
# Got demand data from date 2016-10-03 to 2016-10-06 and its count is 1056
# Now fetching data from 2016-10-07 to 2016-10-10
# Got demand data from date 2016-10-07 to 2016-10-10 and its count is 1056
# Now fetching data from 2016-10-11 to 2016-10-14
# Got demand data from date 2016-10-11 to 2016-10-14 and its count is 1056
# Now fetching data from 2016-10-15 to 2016-10-18
# Got demand data from date 2016-10-15 to 2016-10-18 and its count is 1056
# Now fetching data from 2016-10-19 to 2016-10-22
# Got demand data from date 2016-10-19 to 2016-10-22 and its count is 1056
# Now fetching data from 2016-10-23 to 2016-10-26
# Got demand data from date 2016-10-23 to 2016-10-26 and its count is 1056
# Now fetching data from 2016-10-27 to 2016-10-30
# Got demand data from date 2016-10-27 to 2016-10-30 and its count is 1056
# Now fetching data from 2016-10-31 to 2016-11-03
# Got demand data from date 2016-10-31 to 2016-11-03 and its count is 1056
# Now fetching data from 2016-11-04 to 2016-11-07
# Got demand data from date 2016-11-04 to 2016-11-07 and its count is 1056
# Now fetching data from 2016-11-08 to 2016-11-11
# Got demand data from date 2016-11-08 to 2016-11-11 and its count is 1056
# Now fetching data from 2016-11-12 to 2016-11-15
# Got demand data from date 2016-11-12 to 2016-11-15 and its count is 1056
# Now fetching data from 2016-11-16 to 2016-11-19
# Got demand data from date 2016-11-16 to 2016-11-19 and its count is 1056
# Now fetching data from 2016-11-20 to 2016-11-23
# Got demand data from date 2016-11-20 to 2016-11-23 and its count is 1056
# Now fetching data from 2016-11-24 to 2016-11-27
# Got demand data from date 2016-11-24 to 2016-11-27 and its count is 1056
# Now fetching data from 2016-11-28 to 2016-12-01
# Got demand data from date 2016-11-28 to 2016-12-01 and its count is 1056
# Now fetching data from 2016-12-02 to 2016-12-05
# Got demand data from date 2016-12-02 to 2016-12-05 and its count is 1056
# Now fetching data from 2016-12-06 to 2016-12-09
# Got demand data from date 2016-12-06 to 2016-12-09 and its count is 1056
# Now fetching data from 2016-12-10 to 2016-12-13
# Got demand data from date 2016-12-10 to 2016-12-13 and its count is 1056
# Now fetching data from 2016-12-14 to 2016-12-17
# Got demand data from date 2016-12-14 to 2016-12-17 and its count is 1056
# Now fetching data from 2016-12-18 to 2016-12-21
# Got demand data from date 2016-12-18 to 2016-12-21 and its count is 1056
# Now fetching data from 2016-12-22 to 2016-12-25
# Got demand data from date 2016-12-22 to 2016-12-25 and its count is 1056
# Now fetching data from 2016-12-26 to 2016-12-29
# Got demand data from date 2016-12-26 to 2016-12-29 and its count is 1056
# Now fetching data from 2016-12-30 to 2017-01-02
# Got demand data from date 2016-12-30 to 2017-01-02 and its count is 1056
# Now fetching data from 2017-01-03 to 2017-01-06
# Got demand data from date 2017-01-03 to 2017-01-06 and its count is 1056
# Now fetching data from 2017-01-07 to 2017-01-10
# Got demand data from date 2017-01-07 to 2017-01-10 and its count is 1056
# Now fetching data from 2017-01-11 to 2017-01-14
# Got demand data from date 2017-01-11 to 2017-01-14 and its count is 1056
# Now fetching data from 2017-01-15 to 2017-01-18
# Got demand data from date 2017-01-15 to 2017-01-18 and its count is 1056
# Now fetching data from 2017-01-19 to 2017-01-22
# Got demand data from date 2017-01-19 to 2017-01-22 and its count is 1056
# Now fetching data from 2017-01-23 to 2017-01-26
# Got demand data from date 2017-01-23 to 2017-01-26 and its count is 1056
# Now fetching data from 2017-01-27 to 2017-01-30
# Got demand data from date 2017-01-27 to 2017-01-30 and its count is 1056
# Now fetching data from 2017-01-31 to 2017-02-03
# Got demand data from date 2017-01-31 to 2017-02-03 and its count is 1056
# Now fetching data from 2017-02-04 to 2017-02-07
# Got demand data from date 2017-02-04 to 2017-02-07 and its count is 1056
# Now fetching data from 2017-02-08 to 2017-02-11
# Got demand data from date 2017-02-08 to 2017-02-11 and its count is 1056
# Now fetching data from 2017-02-12 to 2017-02-15
# Got demand data from date 2017-02-12 to 2017-02-15 and its count is 1056
# Now fetching data from 2017-02-16 to 2017-02-19
# Got demand data from date 2017-02-16 to 2017-02-19 and its count is 1056
# Now fetching data from 2017-02-20 to 2017-02-23
# Got demand data from date 2017-02-20 to 2017-02-23 and its count is 1056
# Now fetching data from 2017-02-24 to 2017-02-27
# Got demand data from date 2017-02-24 to 2017-02-27 and its count is 1056
# Now fetching data from 2017-02-28 to 2017-03-03
# Got demand data from date 2017-02-28 to 2017-03-03 and its count is 1056
# Now fetching data from 2017-03-04 to 2017-03-07
# Got demand data from date 2017-03-04 to 2017-03-07 and its count is 1056
# Now fetching data from 2017-03-08 to 2017-03-11
# Got demand data from date 2017-03-08 to 2017-03-11 and its count is 1056
# Now fetching data from 2017-03-12 to 2017-03-15
# Got demand data from date 2017-03-12 to 2017-03-15 and its count is 1056
# Now fetching data from 2017-03-16 to 2017-03-19
# Got demand data from date 2017-03-16 to 2017-03-19 and its count is 1056
# Now fetching data from 2017-03-20 to 2017-03-23
# Got demand data from date 2017-03-20 to 2017-03-23 and its count is 1056
# Now fetching data from 2017-03-24 to 2017-03-27
# Got demand data from date 2017-03-24 to 2017-03-27 and its count is 1056
# Now fetching data from 2017-03-28 to 2017-03-31
# Got demand data from date 2017-03-28 to 2017-03-31 and its count is 1056
# Now fetching data from 2017-04-01 to 2017-04-04
# Got demand data from date 2017-04-01 to 2017-04-04 and its count is 1056
# Now fetching data from 2017-04-05 to 2017-04-08
# Got demand data from date 2017-04-05 to 2017-04-08 and its count is 1056
# Now fetching data from 2017-04-09 to 2017-04-12
# Got demand data from date 2017-04-09 to 2017-04-12 and its count is 1056
# Now fetching data from 2017-04-13 to 2017-04-16
# Got demand data from date 2017-04-13 to 2017-04-16 and its count is 1056
# Now fetching data from 2017-04-17 to 2017-04-20
# Got demand data from date 2017-04-17 to 2017-04-20 and its count is 1056
# Now fetching data from 2017-04-21 to 2017-04-24
# Got demand data from date 2017-04-21 to 2017-04-24 and its count is 1056
# Now fetching data from 2017-04-25 to 2017-04-28
# Got demand data from date 2017-04-25 to 2017-04-28 and its count is 1056
# Now fetching data from 2017-04-29 to 2017-05-02
# Got demand data from date 2017-04-29 to 2017-05-02 and its count is 1056
# Now fetching data from 2017-05-03 to 2017-05-06
# Got demand data from date 2017-05-03 to 2017-05-06 and its count is 1056
# Now fetching data from 2017-05-07 to 2017-05-10
# Got demand data from date 2017-05-07 to 2017-05-10 and its count is 1056
# Now fetching data from 2017-05-11 to 2017-05-14
# Got demand data from date 2017-05-11 to 2017-05-14 and its count is 1056
# Now fetching data from 2017-05-15 to 2017-05-18
# Got demand data from date 2017-05-15 to 2017-05-18 and its count is 1056
# Now fetching data from 2017-05-19 to 2017-05-22
# Got demand data from date 2017-05-19 to 2017-05-22 and its count is 1056
# Now fetching data from 2017-05-23 to 2017-05-26
# Got demand data from date 2017-05-23 to 2017-05-26 and its count is 1056
# Now fetching data from 2017-05-27 to 2017-05-30
# Got demand data from date 2017-05-27 to 2017-05-30 and its count is 1056
# Now fetching data from 2017-05-31 to 2017-06-03
# Got demand data from date 2017-05-31 to 2017-06-03 and its count is 1056
# Now fetching data from 2017-06-04 to 2017-06-07
# Got demand data from date 2017-06-04 to 2017-06-07 and its count is 1056
# Now fetching data from 2017-06-08 to 2017-06-11
# Got demand data from date 2017-06-08 to 2017-06-11 and its count is 1056
# Now fetching data from 2017-06-12 to 2017-06-15
# Got demand data from date 2017-06-12 to 2017-06-15 and its count is 1056
# Now fetching data from 2017-06-16 to 2017-06-19
# Got demand data from date 2017-06-16 to 2017-06-19 and its count is 1056
# Now fetching data from 2017-06-20 to 2017-06-23
# Got demand data from date 2017-06-20 to 2017-06-23 and its count is 1056
# Now fetching data from 2017-06-24 to 2017-06-27
# Got demand data from date 2017-06-24 to 2017-06-27 and its count is 1056
# Now fetching data from 2017-06-28 to 2017-07-01
# Got demand data from date 2017-06-28 to 2017-07-01 and its count is 1056
# Now fetching data from 2017-07-02 to 2017-07-05
# Got demand data from date 2017-07-02 to 2017-07-05 and its count is 1056
# Now fetching data from 2017-07-06 to 2017-07-09
# Got demand data from date 2017-07-06 to 2017-07-09 and its count is 1056
# Now fetching data from 2017-07-10 to 2017-07-13
# Got demand data from date 2017-07-10 to 2017-07-13 and its count is 1056
# Now fetching data from 2017-07-14 to 2017-07-17
# Got demand data from date 2017-07-14 to 2017-07-17 and its count is 1056
# Now fetching data from 2017-07-18 to 2017-07-21
# Got demand data from date 2017-07-18 to 2017-07-21 and its count is 1056
# Now fetching data from 2017-07-22 to 2017-07-25
# Got demand data from date 2017-07-22 to 2017-07-25 and its count is 1056
# Now fetching data from 2017-07-26 to 2017-07-29
# Got demand data from date 2017-07-26 to 2017-07-29 and its count is 1056
# Now fetching data from 2017-07-30 to 2017-08-02
# Got demand data from date 2017-07-30 to 2017-08-02 and its count is 1056
# Now fetching data from 2017-08-03 to 2017-08-06
# Got demand data from date 2017-08-03 to 2017-08-06 and its count is 1056
# Now fetching data from 2017-08-07 to 2017-08-10
# Got demand data from date 2017-08-07 to 2017-08-10 and its count is 1056
# Now fetching data from 2017-08-11 to 2017-08-14
# Got demand data from date 2017-08-11 to 2017-08-14 and its count is 1056
# Now fetching data from 2017-08-15 to 2017-08-18
# Got demand data from date 2017-08-15 to 2017-08-18 and its count is 1056
# Now fetching data from 2017-08-19 to 2017-08-22
# Got demand data from date 2017-08-19 to 2017-08-22 and its count is 1056
# Now fetching data from 2017-08-23 to 2017-08-26
# Got demand data from date 2017-08-23 to 2017-08-26 and its count is 1056
# Now fetching data from 2017-08-27 to 2017-08-30
# Got demand data from date 2017-08-27 to 2017-08-30 and its count is 1056
# Now fetching data from 2017-08-31 to 2017-09-03
# Got demand data from date 2017-08-31 to 2017-09-03 and its count is 1056
# Now fetching data from 2017-09-04 to 2017-09-07
# Got demand data from date 2017-09-04 to 2017-09-07 and its count is 1056
# Now fetching data from 2017-09-08 to 2017-09-11
# Got demand data from date 2017-09-08 to 2017-09-11 and its count is 1056
# Now fetching data from 2017-09-12 to 2017-09-15
# Got demand data from date 2017-09-12 to 2017-09-15 and its count is 1056
# Now fetching data from 2017-09-16 to 2017-09-19
# Got demand data from date 2017-09-16 to 2017-09-19 and its count is 1056
# Now fetching data from 2017-09-20 to 2017-09-23
# Got demand data from date 2017-09-20 to 2017-09-23 and its count is 1056
# Now fetching data from 2017-09-24 to 2017-09-27
# Got demand data from date 2017-09-24 to 2017-09-27 and its count is 1056
# Now fetching data from 2017-09-28 to 2017-10-01
# Got demand data from date 2017-09-28 to 2017-10-01 and its count is 1056
# Now fetching data from 2017-10-02 to 2017-10-05
# Got demand data from date 2017-10-02 to 2017-10-05 and its count is 1056
# Now fetching data from 2017-10-06 to 2017-10-09
# Got demand data from date 2017-10-06 to 2017-10-09 and its count is 1056
# Now fetching data from 2017-10-10 to 2017-10-13
# Got demand data from date 2017-10-10 to 2017-10-13 and its count is 1056
# Now fetching data from 2017-10-14 to 2017-10-17
# Got demand data from date 2017-10-14 to 2017-10-17 and its count is 1056
# Now fetching data from 2017-10-18 to 2017-10-21
# Got demand data from date 2017-10-18 to 2017-10-21 and its count is 1056
# Now fetching data from 2017-10-22 to 2017-10-25
# Got demand data from date 2017-10-22 to 2017-10-25 and its count is 1056
# Now fetching data from 2017-10-26 to 2017-10-29
# Got demand data from date 2017-10-26 to 2017-10-29 and its count is 1056
# Now fetching data from 2017-10-30 to 2017-11-02
# Got demand data from date 2017-10-30 to 2017-11-02 and its count is 1056
# Now fetching data from 2017-11-03 to 2017-11-06
# Got demand data from date 2017-11-03 to 2017-11-06 and its count is 1056
# Now fetching data from 2017-11-07 to 2017-11-10
# Got demand data from date 2017-11-07 to 2017-11-10 and its count is 1056
# Now fetching data from 2017-11-11 to 2017-11-14
# Got demand data from date 2017-11-11 to 2017-11-14 and its count is 1056
# Now fetching data from 2017-11-15 to 2017-11-18
# Got demand data from date 2017-11-15 to 2017-11-18 and its count is 1056
# Now fetching data from 2017-11-19 to 2017-11-22
# Got demand data from date 2017-11-19 to 2017-11-22 and its count is 1056
# Now fetching data from 2017-11-23 to 2017-11-26
# Got demand data from date 2017-11-23 to 2017-11-26 and its count is 1056
# Now fetching data from 2017-11-27 to 2017-11-30
# Got demand data from date 2017-11-27 to 2017-11-30 and its count is 1056
# Now fetching data from 2017-12-01 to 2017-12-04
# Got demand data from date 2017-12-01 to 2017-12-04 and its count is 1056
# Now fetching data from 2017-12-05 to 2017-12-08
# Got demand data from date 2017-12-05 to 2017-12-08 and its count is 1056
# Now fetching data from 2017-12-09 to 2017-12-12
# Got demand data from date 2017-12-09 to 2017-12-12 and its count is 1056
# Now fetching data from 2017-12-13 to 2017-12-16
# Got demand data from date 2017-12-13 to 2017-12-16 and its count is 1056
# Now fetching data from 2017-12-17 to 2017-12-20
# Got demand data from date 2017-12-17 to 2017-12-20 and its count is 1056
# Now fetching data from 2017-12-21 to 2017-12-24
# Got demand data from date 2017-12-21 to 2017-12-24 and its count is 1056
# Now fetching data from 2017-12-25 to 2017-12-28
# Got demand data from date 2017-12-25 to 2017-12-28 and its count is 1056
# Now fetching data from 2017-12-29 to 2018-01-01
# Got demand data from date 2017-12-29 to 2018-01-01 and its count is 1056
# Now fetching data from 2018-01-02 to 2018-01-05
# Got demand data from date 2018-01-02 to 2018-01-05 and its count is 1056
# Now fetching data from 2018-01-06 to 2018-01-09
# Got demand data from date 2018-01-06 to 2018-01-09 and its count is 1056
# Now fetching data from 2018-01-10 to 2018-01-13
# Got demand data from date 2018-01-10 to 2018-01-13 and its count is 1056
# Now fetching data from 2018-01-14 to 2018-01-17
# Got demand data from date 2018-01-14 to 2018-01-17 and its count is 1056
# Now fetching data from 2018-01-18 to 2018-01-21
# Got demand data from date 2018-01-18 to 2018-01-21 and its count is 1056
# Now fetching data from 2018-01-22 to 2018-01-25
# Got demand data from date 2018-01-22 to 2018-01-25 and its count is 1056
# Now fetching data from 2018-01-26 to 2018-01-29
# Got demand data from date 2018-01-26 to 2018-01-29 and its count is 1056
# Now fetching data from 2018-01-30 to 2018-02-02
# Got demand data from date 2018-01-30 to 2018-02-02 and its count is 1056
# Now fetching data from 2018-02-03 to 2018-02-06
# Got demand data from date 2018-02-03 to 2018-02-06 and its count is 1056
# Now fetching data from 2018-02-07 to 2018-02-10
# Got demand data from date 2018-02-07 to 2018-02-10 and its count is 1056
# Now fetching data from 2018-02-11 to 2018-02-14
# Got demand data from date 2018-02-11 to 2018-02-14 and its count is 1056
# Now fetching data from 2018-02-15 to 2018-02-18
# Got demand data from date 2018-02-15 to 2018-02-18 and its count is 1056
# Now fetching data from 2018-02-19 to 2018-02-22
# Got demand data from date 2018-02-19 to 2018-02-22 and its count is 1056
# Now fetching data from 2018-02-23 to 2018-02-26
# Got demand data from date 2018-02-23 to 2018-02-26 and its count is 1056
# Now fetching data from 2018-02-27 to 2018-03-02
# Got demand data from date 2018-02-27 to 2018-03-02 and its count is 1056
# Now fetching data from 2018-03-03 to 2018-03-06
# Got demand data from date 2018-03-03 to 2018-03-06 and its count is 1056
# Now fetching data from 2018-03-07 to 2018-03-10
# Got demand data from date 2018-03-07 to 2018-03-10 and its count is 1056
# Now fetching data from 2018-03-11 to 2018-03-14
# Got demand data from date 2018-03-11 to 2018-03-14 and its count is 1056
# Now fetching data from 2018-03-15 to 2018-03-18
# Got demand data from date 2018-03-15 to 2018-03-18 and its count is 1056
# Now fetching data from 2018-03-19 to 2018-03-22
# Got demand data from date 2018-03-19 to 2018-03-22 and its count is 1056
# Now fetching data from 2018-03-23 to 2018-03-26
# Got demand data from date 2018-03-23 to 2018-03-26 and its count is 1056
# Now fetching data from 2018-03-27 to 2018-03-30
# Got demand data from date 2018-03-27 to 2018-03-30 and its count is 1056
# Now fetching data from 2018-03-31 to 2018-04-03
# Got demand data from date 2018-03-31 to 2018-04-03 and its count is 1056
# Now fetching data from 2018-04-04 to 2018-04-07
# Got demand data from date 2018-04-04 to 2018-04-07 and its count is 1056
# Now fetching data from 2018-04-08 to 2018-04-11
# Got demand data from date 2018-04-08 to 2018-04-11 and its count is 1056
# Now fetching data from 2018-04-12 to 2018-04-15
# Got demand data from date 2018-04-12 to 2018-04-15 and its count is 1056
# Now fetching data from 2018-04-16 to 2018-04-19
# Got demand data from date 2018-04-16 to 2018-04-19 and its count is 1056
# Now fetching data from 2018-04-20 to 2018-04-23
# Got demand data from date 2018-04-20 to 2018-04-23 and its count is 1056
# Now fetching data from 2018-04-24 to 2018-04-27
# Got demand data from date 2018-04-24 to 2018-04-27 and its count is 1056
# Now fetching data from 2018-04-28 to 2018-05-01
# Got demand data from date 2018-04-28 to 2018-05-01 and its count is 1056
# Now fetching data from 2018-05-02 to 2018-05-05
# Got demand data from date 2018-05-02 to 2018-05-05 and its count is 1056
# Now fetching data from 2018-05-06 to 2018-05-09
# Got demand data from date 2018-05-06 to 2018-05-09 and its count is 1056
# Now fetching data from 2018-05-10 to 2018-05-13
# Got demand data from date 2018-05-10 to 2018-05-13 and its count is 1056
# Now fetching data from 2018-05-14 to 2018-05-17
# Got demand data from date 2018-05-14 to 2018-05-17 and its count is 1056
# Now fetching data from 2018-05-18 to 2018-05-21
# Got demand data from date 2018-05-18 to 2018-05-21 and its count is 1056
# Now fetching data from 2018-05-22 to 2018-05-25
# Got demand data from date 2018-05-22 to 2018-05-25 and its count is 1056
# Now fetching data from 2018-05-26 to 2018-05-29
# Got demand data from date 2018-05-26 to 2018-05-29 and its count is 1056
# Now fetching data from 2018-05-30 to 2018-06-02
# Got demand data from date 2018-05-30 to 2018-06-02 and its count is 1056
# Now fetching data from 2018-06-03 to 2018-06-06
# Got demand data from date 2018-06-03 to 2018-06-06 and its count is 1056
# Now fetching data from 2018-06-07 to 2018-06-10
# Got demand data from date 2018-06-07 to 2018-06-10 and its count is 1056
# Now fetching data from 2018-06-11 to 2018-06-14
# Got demand data from date 2018-06-11 to 2018-06-14 and its count is 1056
# Now fetching data from 2018-06-15 to 2018-06-18
# Got demand data from date 2018-06-15 to 2018-06-18 and its count is 1056
# Now fetching data from 2018-06-19 to 2018-06-22
# Got demand data from date 2018-06-19 to 2018-06-22 and its count is 1056
# Now fetching data from 2018-06-23 to 2018-06-26
# Got demand data from date 2018-06-23 to 2018-06-26 and its count is 1056
# Now fetching data from 2018-06-27 to 2018-06-30
# Got demand data from date 2018-06-27 to 2018-06-30 and its count is 1056
# Now fetching data from 2018-07-01 to 2018-07-04
# /workspace/VoltWise/.venv/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /workspace/VoltWise/.venv/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Data Correction
# ['2018-07-01', '2018-07-02', '2018-07-03', '2018-07-04']
# Got demand data from date 2018-07-01 to 2018-07-04 and its count is 1056
# Now fetching data from 2018-07-05 to 2018-07-08
# Got demand data from date 2018-07-05 to 2018-07-08 and its count is 1056
# Now fetching data from 2018-07-09 to 2018-07-12
# Got demand data from date 2018-07-09 to 2018-07-12 and its count is 1056
# Now fetching data from 2018-07-13 to 2018-07-16
# Got demand data from date 2018-07-13 to 2018-07-16 and its count is 1056
# Now fetching data from 2018-07-17 to 2018-07-20
# Got demand data from date 2018-07-17 to 2018-07-20 and its count is 1056
# Now fetching data from 2018-07-21 to 2018-07-24
# Got demand data from date 2018-07-21 to 2018-07-24 and its count is 1056
# Now fetching data from 2018-07-25 to 2018-07-28
# Got demand data from date 2018-07-25 to 2018-07-28 and its count is 1056
# Now fetching data from 2018-07-29 to 2018-08-01
# Got demand data from date 2018-07-29 to 2018-08-01 and its count is 1056
# Now fetching data from 2018-08-02 to 2018-08-05
# Got demand data from date 2018-08-02 to 2018-08-05 and its count is 1056
# Now fetching data from 2018-08-06 to 2018-08-09
# Got demand data from date 2018-08-06 to 2018-08-09 and its count is 1056
# Now fetching data from 2018-08-10 to 2018-08-13
# Got demand data from date 2018-08-10 to 2018-08-13 and its count is 1056
# Now fetching data from 2018-08-14 to 2018-08-17
# Got demand data from date 2018-08-14 to 2018-08-17 and its count is 1056
# Now fetching data from 2018-08-18 to 2018-08-21
# Got demand data from date 2018-08-18 to 2018-08-21 and its count is 1056
# Now fetching data from 2018-08-22 to 2018-08-25
# Got demand data from date 2018-08-22 to 2018-08-25 and its count is 1056
# Now fetching data from 2018-08-26 to 2018-08-29
# Got demand data from date 2018-08-26 to 2018-08-29 and its count is 1056
# Now fetching data from 2018-08-30 to 2018-09-02
# Got demand data from date 2018-08-30 to 2018-09-02 and its count is 1056
# Now fetching data from 2018-09-03 to 2018-09-06
# Got demand data from date 2018-09-03 to 2018-09-06 and its count is 1056
# Now fetching data from 2018-09-07 to 2018-09-10
# Got demand data from date 2018-09-07 to 2018-09-10 and its count is 1056
# Now fetching data from 2018-09-11 to 2018-09-14
# Got demand data from date 2018-09-11 to 2018-09-14 and its count is 1056
# Now fetching data from 2018-09-15 to 2018-09-18
# Got demand data from date 2018-09-15 to 2018-09-18 and its count is 1056
# Now fetching data from 2018-09-19 to 2018-09-22
# Got demand data from date 2018-09-19 to 2018-09-22 and its count is 1056
# Now fetching data from 2018-09-23 to 2018-09-26
# Got demand data from date 2018-09-23 to 2018-09-26 and its count is 1056
# Now fetching data from 2018-09-27 to 2018-09-30
# Got demand data from date 2018-09-27 to 2018-09-30 and its count is 1056
# Now fetching data from 2018-10-01 to 2018-10-04
# Got demand data from date 2018-10-01 to 2018-10-04 and its count is 1056
# Now fetching data from 2018-10-05 to 2018-10-08
# Got demand data from date 2018-10-05 to 2018-10-08 and its count is 1056
# Now fetching data from 2018-10-09 to 2018-10-12
# Got demand data from date 2018-10-09 to 2018-10-12 and its count is 1056
# Now fetching data from 2018-10-13 to 2018-10-16
# Got demand data from date 2018-10-13 to 2018-10-16 and its count is 1056
# Now fetching data from 2018-10-17 to 2018-10-20
# Got demand data from date 2018-10-17 to 2018-10-20 and its count is 1056
# Now fetching data from 2018-10-21 to 2018-10-24
# Got demand data from date 2018-10-21 to 2018-10-24 and its count is 1056
# Now fetching data from 2018-10-25 to 2018-10-28
# Got demand data from date 2018-10-25 to 2018-10-28 and its count is 1056
# Now fetching data from 2018-10-29 to 2018-11-01
# Got demand data from date 2018-10-29 to 2018-11-01 and its count is 1056
# Now fetching data from 2018-11-02 to 2018-11-05
# Got demand data from date 2018-11-02 to 2018-11-05 and its count is 1056
# Now fetching data from 2018-11-06 to 2018-11-09
# Got demand data from date 2018-11-06 to 2018-11-09 and its count is 1056
# Now fetching data from 2018-11-10 to 2018-11-13
# /workspace/VoltWise/.venv/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# /workspace/VoltWise/.venv/lib/python3.10/site-packages/numpy/lib/nanfunctions.py:1215: RuntimeWarning: Mean of empty slice
#   return np.nanmean(a, axis, out=out, keepdims=keepdims)
# Data Correction
# ['2018-11-10', '2018-11-11', '2018-11-12', '2018-11-13']
# Got demand data from date 2018-11-10 to 2018-11-13 and its count is 1056
# Now fetching data from 2018-11-14 to 2018-11-17
# Got demand data from date 2018-11-14 to 2018-11-17 and its count is 1056
# Now fetching data from 2018-11-18 to 2018-11-21
# Got demand data from date 2018-11-18 to 2018-11-21 and its count is 1056
# Now fetching data from 2018-11-22 to 2018-11-25
# Got demand data from date 2018-11-22 to 2018-11-25 and its count is 1056
# Now fetching data from 2018-11-26 to 2018-11-29
# Got demand data from date 2018-11-26 to 2018-11-29 and its count is 1056
# Now fetching data from 2018-11-30 to 2018-12-03
# Got demand data from date 2018-11-30 to 2018-12-03 and its count is 1056
# Now fetching data from 2018-12-04 to 2018-12-07
# Got demand data from date 2018-12-04 to 2018-12-07 and its count is 1056
# Now fetching data from 2018-12-08 to 2018-12-11
# Got demand data from date 2018-12-08 to 2018-12-11 and its count is 1056
# Now fetching data from 2018-12-12 to 2018-12-15
# Got demand data from date 2018-12-12 to 2018-12-15 and its count is 1056
# Now fetching data from 2018-12-16 to 2018-12-19
# Got demand data from date 2018-12-16 to 2018-12-19 and its count is 1056
# Now fetching data from 2018-12-20 to 2018-12-23
# Got demand data from date 2018-12-20 to 2018-12-23 and its count is 1056
# Now fetching data from 2018-12-24 to 2018-12-27
# Got demand data from date 2018-12-24 to 2018-12-27 and its count is 1056
# Now fetching data from 2018-12-28 to 2018-12-31
# Got demand data from date 2018-12-28 to 2018-12-31 and its count is 1056
# Now fetching data from 2019-01-01 to 2019-01-04
# Got demand data from date 2019-01-01 to 2019-01-04 and its count is 1056
# Now fetching data from 2019-01-05 to 2019-01-08
# Got demand data from date 2019-01-05 to 2019-01-08 and its count is 1056
# Now fetching data from 2019-01-09 to 2019-01-12
# Got demand data from date 2019-01-09 to 2019-01-12 and its count is 1056
# Now fetching data from 2019-01-13 to 2019-01-16
# Got demand data from date 2019-01-13 to 2019-01-16 and its count is 1056
# Now fetching data from 2019-01-17 to 2019-01-20
# Got demand data from date 2019-01-17 to 2019-01-20 and its count is 1056
# Now fetching data from 2019-01-21 to 2019-01-24
# Got demand data from date 2019-01-21 to 2019-01-24 and its count is 1056
# Now fetching data from 2019-01-25 to 2019-01-28
# Got demand data from date 2019-01-25 to 2019-01-28 and its count is 1056
# Now fetching data from 2019-01-29 to 2019-02-01
# Got demand data from date 2019-01-29 to 2019-02-01 and its count is 1056
# Now fetching data from 2019-02-02 to 2019-02-05
# Got demand data from date 2019-02-02 to 2019-02-05 and its count is 1056
# Now fetching data from 2019-02-06 to 2019-02-09
# Got demand data from date 2019-02-06 to 2019-02-09 and its count is 1056
# Now fetching data from 2019-02-10 to 2019-02-13
# Got demand data from date 2019-02-10 to 2019-02-13 and its count is 1056
# Now fetching data from 2019-02-14 to 2019-02-17
# Got demand data from date 2019-02-14 to 2019-02-17 and its count is 1056
# Now fetching data from 2019-02-18 to 2019-02-21
# Got demand data from date 2019-02-18 to 2019-02-21 and its count is 1056
# Now fetching data from 2019-02-22 to 2019-02-25
# Got demand data from date 2019-02-22 to 2019-02-25 and its count is 1056
# Now fetching data from 2019-02-26 to 2019-03-01
# Got demand data from date 2019-02-26 to 2019-03-01 and its count is 1056
# Now fetching data from 2019-03-02 to 2019-03-05
# Got demand data from date 2019-03-02 to 2019-03-05 and its count is 1056
# Now fetching data from 2019-03-06 to 2019-03-09
# Got demand data from date 2019-03-06 to 2019-03-09 and its count is 1056
# Now fetching data from 2019-03-10 to 2019-03-13
# Got demand data from date 2019-03-10 to 2019-03-13 and its count is 1056
# Now fetching data from 2019-03-14 to 2019-03-17
# Got demand data from date 2019-03-14 to 2019-03-17 and its count is 1056
# Now fetching data from 2019-03-18 to 2019-03-21
# Got demand data from date 2019-03-18 to 2019-03-21 and its count is 1056
# Now fetching data from 2019-03-22 to 2019-03-25
# Got demand data from date 2019-03-22 to 2019-03-25 and its count is 1056
# Now fetching data from 2019-03-26 to 2019-03-29
# Got demand data from date 2019-03-26 to 2019-03-29 and its count is 1056
# Now fetching data from 2019-03-30 to 2019-04-02
# Got demand data from date 2019-03-30 to 2019-04-02 and its count is 1056
# Now fetching data from 2019-04-03 to 2019-04-06
# Got demand data from date 2019-04-03 to 2019-04-06 and its count is 1056
# Now fetching data from 2019-04-07 to 2019-04-10
# Got demand data from date 2019-04-07 to 2019-04-10 and its count is 1056
# Now fetching data from 2019-04-11 to 2019-04-14
# Got demand data from date 2019-04-11 to 2019-04-14 and its count is 1056
# Now fetching data from 2019-04-15 to 2019-04-18
# Got demand data from date 2019-04-15 to 2019-04-18 and its count is 1056
# Now fetching data from 2019-04-19 to 2019-04-22
# Got demand data from date 2019-04-19 to 2019-04-22 and its count is 1056
# Now fetching data from 2019-04-23 to 2019-04-26
# Got demand data from date 2019-04-23 to 2019-04-26 and its count is 1056
# Now fetching data from 2019-04-27 to 2019-04-30
# Got demand data from date 2019-04-27 to 2019-04-30 and its count is 1056
# Now fetching data from 2019-05-01 to 2019-05-04
# Got demand data from date 2019-05-01 to 2019-05-04 and its count is 1056
# Now fetching data from 2019-05-05 to 2019-05-08
# Got demand data from date 2019-05-05 to 2019-05-08 and its count is 1056
# Now fetching data from 2019-05-09 to 2019-05-12
# Got demand data from date 2019-05-09 to 2019-05-12 and its count is 1056
# Now fetching data from 2019-05-13 to 2019-05-16
# Got demand data from date 2019-05-13 to 2019-05-16 and its count is 1056
# Now fetching data from 2019-05-17 to 2019-05-20
# Got demand data from date 2019-05-17 to 2019-05-20 and its count is 1056
# Now fetching data from 2019-05-21 to 2019-05-24
# Got demand data from date 2019-05-21 to 2019-05-24 and its count is 1056
# Now fetching data from 2019-05-25 to 2019-05-28
# Got demand data from date 2019-05-25 to 2019-05-28 and its count is 1056
# Now fetching data from 2019-05-29 to 2019-06-01
# Got demand data from date 2019-05-29 to 2019-06-01 and its count is 1056
# Now fetching data from 2019-06-02 to 2019-06-05
# Got demand data from date 2019-06-02 to 2019-06-05 and its count is 1056
# Now fetching data from 2019-06-06 to 2019-06-09
# Got demand data from date 2019-06-06 to 2019-06-09 and its count is 1056
# Now fetching data from 2019-06-10 to 2019-06-13
# Got demand data from date 2019-06-10 to 2019-06-13 and its count is 1056
# Now fetching data from 2019-06-14 to 2019-06-17
# Got demand data from date 2019-06-14 to 2019-06-17 and its count is 1056
# Now fetching data from 2019-06-18 to 2019-06-21
# Got demand data from date 2019-06-18 to 2019-06-21 and its count is 1056
# Now fetching data from 2019-06-22 to 2019-06-25
# Got demand data from date 2019-06-22 to 2019-06-25 and its count is 1056
# Now fetching data from 2019-06-26 to 2019-06-29
# Got demand data from date 2019-06-26 to 2019-06-29 and its count is 1056
# Now fetching data from 2019-06-30 to 2019-07-03
# Got demand data from date 2019-06-30 to 2019-07-03 and its count is 1056
# Now fetching data from 2019-07-04 to 2019-07-07
# Got demand data from date 2019-07-04 to 2019-07-07 and its count is 1056
# Now fetching data from 2019-07-08 to 2019-07-11
# Got demand data from date 2019-07-08 to 2019-07-11 and its count is 1056
# Now fetching data from 2019-07-12 to 2019-07-15
# Got demand data from date 2019-07-12 to 2019-07-15 and its count is 1056
# Now fetching data from 2019-07-16 to 2019-07-19
# Got demand data from date 2019-07-16 to 2019-07-19 and its count is 1056
# Now fetching data from 2019-07-20 to 2019-07-23
# Got demand data from date 2019-07-20 to 2019-07-23 and its count is 1056
# Now fetching data from 2019-07-24 to 2019-07-27
# Got demand data from date 2019-07-24 to 2019-07-27 and its count is 1056
# Now fetching data from 2019-07-28 to 2019-07-31
# Got demand data from date 2019-07-28 to 2019-07-31 and its count is 1056
# Now fetching data from 2019-08-01 to 2019-08-04
# Got demand data from date 2019-08-01 to 2019-08-04 and its count is 1056
# Now fetching data from 2019-08-05 to 2019-08-08
# Got demand data from date 2019-08-05 to 2019-08-08 and its count is 1056
# Now fetching data from 2019-08-09 to 2019-08-12
# Got demand data from date 2019-08-09 to 2019-08-12 and its count is 1056
# Now fetching data from 2019-08-13 to 2019-08-16
# Got demand data from date 2019-08-13 to 2019-08-16 and its count is 1056
# Now fetching data from 2019-08-17 to 2019-08-20
# Got demand data from date 2019-08-17 to 2019-08-20 and its count is 1056
# Now fetching data from 2019-08-21 to 2019-08-24
# Got demand data from date 2019-08-21 to 2019-08-24 and its count is 1056
# Now fetching data from 2019-08-25 to 2019-08-28
# Got demand data from date 2019-08-25 to 2019-08-28 and its count is 1056
# Now fetching data from 2019-08-29 to 2019-09-01
# Got demand data from date 2019-08-29 to 2019-09-01 and its count is 1056
# Now fetching data from 2019-09-02 to 2019-09-05
# Got demand data from date 2019-09-02 to 2019-09-05 and its count is 1056
# Now fetching data from 2019-09-06 to 2019-09-09
# ...
# Now fetching data from 2022-01-29 to 2022-02-01
# Got demand data from date 2022-01-29 to 2022-02-01 and its count is 1056
# Now fetching data from 2022-02-02 to 2022-02-05
# Got demand data from date 2022-02-02 to 2022-02-05 and its count is 1056
# Now fetching data from 2022-02-06 to 2022-02-09
# Got demand data from date 2022-02-06 to 2022-02-09 and its count is 1056
# Now fetching data from 2022-02-10 to 2022-02-13
# Got demand data from date 2022-02-10 to 2022-02-13 and its count is 1056
# Now fetching data from 2022-02-14 to 2022-02-17
# Got demand data from date 2022-02-14 to 2022-02-17 and its count is 1056
# Now fetching data from 2022-02-18 to 2022-02-21
# Got demand data from date 2022-02-18 to 2022-02-21 and its count is 1056
# Now fetching data from 2022-02-22 to 2022-02-25
# Got demand data from date 2022-02-22 to 2022-02-25 and its count is 1056
# Now fetching data from 2022-02-26 to 2022-03-01
# Got demand data from date 2022-02-26 to 2022-03-01 and its count is 1056
# Now fetching data from 2022-03-02 to 2022-03-05
# Got demand data from date 2022-03-02 to 2022-03-05 and its count is 1056
# Now fetching data from 2022-03-06 to 2022-03-09
# Got demand data from date 2022-03-06 to 2022-03-09 and its count is 1056
# Now fetching data from 2022-03-10 to 2022-03-13
# Got demand data from date 2022-03-10 to 2022-03-13 and its count is 1056
# Now fetching data from 2022-03-14 to 2022-03-17
# Got demand data from date 2022-03-14 to 2022-03-17 and its count is 1056
# Now fetching data from 2022-03-18 to 2022-03-21
# Got demand data from date 2022-03-18 to 2022-03-21 and its count is 1056
# Now fetching data from 2022-03-22 to 2022-03-25
# Got demand data from date 2022-03-22 to 2022-03-25 and its count is 1056
# Now fetching data from 2022-03-26 to 2022-03-29
# Got demand data from date 2022-03-26 to 2022-03-29 and its count is 1056
# Now fetching data from 2022-03-30 to 2022-04-02
# Got demand data from date 2022-03-30 to 2022-04-02 and its count is 1056
# Now fetching data from 2022-04-03 to 2022-04-06
# Got demand data from date 2022-04-03 to 2022-04-06 and its count is 1056
# Now fetching data from 2022-04-07 to 2022-04-10
# Got demand data from date 2022-04-07 to 2022-04-10 and its count is 1056
# Now fetching data from 2022-04-11 to 2022-04-14
# Got demand data from date 2022-04-11 to 2022-04-14 and its count is 1056
# Now fetching data from 2022-04-15 to 2022-04-18
# Got demand data from date 2022-04-15 to 2022-04-18 and its count is 1056
# Now fetching data from 2022-04-19 to 2022-04-22
# Got demand data from date 2022-04-19 to 2022-04-22 and its count is 1056
# Now fetching data from 2022-04-23 to 2022-04-26
# Got demand data from date 2022-04-23 to 2022-04-26 and its count is 1056
# Now fetching data from 2022-04-27 to 2022-04-30
# Got demand data from date 2022-04-27 to 2022-04-30 and its count is 1056
# Now fetching data from 2022-05-01 to 2022-05-04
# Got demand data from date 2022-05-01 to 2022-05-04 and its count is 1056
# Now fetching data from 2022-05-05 to 2022-05-08
# Got demand data from date 2022-05-05 to 2022-05-08 and its count is 1056
# Now fetching data from 2022-05-09 to 2022-05-12
# Got demand data from date 2022-05-09 to 2022-05-12 and its count is 1056
# Now fetching data from 2022-05-13 to 2022-05-16
# Got demand data from date 2022-05-13 to 2022-05-16 and its count is 1056
# Now fetching data from 2022-05-17 to 2022-05-20
# Got demand data from date 2022-05-17 to 2022-05-20 and its count is 1056
# Now fetching data from 2022-05-21 to 2022-05-24
# Got demand data from date 2022-05-21 to 2022-05-24 and its count is 1056
# Now fetching data from 2022-05-25 to 2022-05-28
# Got demand data from date 2022-05-25 to 2022-05-28 and its count is 1056
# Now fetching data from 2022-05-29 to 2022-06-01
# Got demand data from date 2022-05-29 to 2022-06-01 and its count is 1056
# Now fetching data from 2022-06-02 to 2022-06-05
# Got demand data from date 2022-06-02 to 2022-06-05 and its count is 1056
# Now fetching data from 2022-06-06 to 2022-06-09
# Got demand data from date 2022-06-06 to 2022-06-09 and its count is 1056
# Now fetching data from 2022-06-10 to 2022-06-13
# Got demand data from date 2022-06-10 to 2022-06-13 and its count is 1056
# Now fetching data from 2022-06-14 to 2022-06-17
# Got demand data from date 2022-06-14 to 2022-06-17 and its count is 1056
# Now fetching data from 2022-06-18 to 2022-06-21
# Got demand data from date 2022-06-18 to 2022-06-21 and its count is 1056
# Now fetching data from 2022-06-22 to 2022-06-25
# Got demand data from date 2022-06-22 to 2022-06-25 and its count is 1056
# Now fetching data from 2022-06-26 to 2022-06-29
# Got demand data from date 2022-06-26 to 2022-06-29 and its count is 1056
# Now fetching data from 2022-06-30 to 2022-07-03
# Got demand data from date 2022-06-30 to 2022-07-03 and its count is 1056
# Now fetching data from 2022-07-04 to 2022-07-07
# Got demand data from date 2022-07-04 to 2022-07-07 and its count is 1056
# Now fetching data from 2022-07-08 to 2022-07-11
# Got demand data from date 2022-07-08 to 2022-07-11 and its count is 1056
# Now fetching data from 2022-07-12 to 2022-07-15
# Got demand data from date 2022-07-12 to 2022-07-15 and its count is 1056
# Now fetching data from 2022-07-16 to 2022-07-19
# Got demand data from date 2022-07-16 to 2022-07-19 and its count is 1056
# Now fetching data from 2022-07-20 to 2022-07-23
# Got demand data from date 2022-07-20 to 2022-07-23 and its count is 1056
# Now fetching data from 2022-07-24 to 2022-07-27
# Got demand data from date 2022-07-24 to 2022-07-27 and its count is 1056
# Now fetching data from 2022-07-28 to 2022-07-31
# Got demand data from date 2022-07-28 to 2022-07-31 and its count is 1056
# Now fetching data from 2022-08-01 to 2022-08-04
# Got demand data from date 2022-08-01 to 2022-08-04 and its count is 1056
# Now fetching data from 2022-08-05 to 2022-08-08
# Got demand data from date 2022-08-05 to 2022-08-08 and its count is 1056
# Now fetching data from 2022-08-09 to 2022-08-12
# Got demand data from date 2022-08-09 to 2022-08-12 and its count is 1056
# Now fetching data from 2022-08-13 to 2022-08-16
# Got demand data from date 2022-08-13 to 2022-08-16 and its count is 1056
# Now fetching data from 2022-08-17 to 2022-08-20
# Got demand data from date 2022-08-17 to 2022-08-20 and its count is 1056
# Now fetching data from 2022-08-21 to 2022-08-24
# Got demand data from date 2022-08-21 to 2022-08-24 and its count is 1056
# Now fetching data from 2022-08-25 to 2022-08-28
# Got demand data from date 2022-08-25 to 2022-08-28 and its count is 1056
# Now fetching data from 2022-08-29 to 2022-09-01
# Got demand data from date 2022-08-29 to 2022-09-01 and its count is 1056
# Now fetching data from 2022-09-02 to 2022-09-05
# Got demand data from date 2022-09-02 to 2022-09-05 and its count is 1056
# Now fetching data from 2022-09-06 to 2022-09-09
# Got demand data from date 2022-09-06 to 2022-09-09 and its count is 1056
# Now fetching data from 2022-09-10 to 2022-09-13
# Got demand data from date 2022-09-10 to 2022-09-13 and its count is 1056
# Now fetching data from 2022-09-14 to 2022-09-17
# Got demand data from date 2022-09-14 to 2022-09-17 and its count is 1056
# Now fetching data from 2022-09-18 to 2022-09-21
# Got demand data from date 2022-09-18 to 2022-09-21 and its count is 1056
# Now fetching data from 2022-09-22 to 2022-09-25
# Got demand data from date 2022-09-22 to 2022-09-25 and its count is 1056
# Now fetching data from 2022-09-26 to 2022-09-29
# Got demand data from date 2022-09-26 to 2022-09-29 and its count is 1056
# Now fetching data from 2022-09-30 to 2022-10-03
# Got demand data from date 2022-09-30 to 2022-10-03 and its count is 1056
# Now fetching data from 2022-10-04 to 2022-10-07
# Got demand data from date 2022-10-04 to 2022-10-07 and its count is 1056
# Now fetching data from 2022-10-08 to 2022-10-11
# Got demand data from date 2022-10-08 to 2022-10-11 and its count is 1056
# Now fetching data from 2022-10-12 to 2022-10-15
# Got demand data from date 2022-10-12 to 2022-10-15 and its count is 1056
# Now fetching data from 2022-10-16 to 2022-10-19
# Got demand data from date 2022-10-16 to 2022-10-19 and its count is 1056
# Now fetching data from 2022-10-20 to 2022-10-23
# Got demand data from date 2022-10-20 to 2022-10-23 and its count is 1056
# Now fetching data from 2022-10-24 to 2022-10-27
# Got demand data from date 2022-10-24 to 2022-10-27 and its count is 1056
# Now fetching data from 2022-10-28 to 2022-10-31
# Got demand data from date 2022-10-28 to 2022-10-31 and its count is 1056
# Now fetching data from 2022-11-01 to 2022-11-04
# Got demand data from date 2022-11-01 to 2022-11-04 and its count is 1056
# Now fetching data from 2022-11-05 to 2022-11-08
# Got demand data from date 2022-11-05 to 2022-11-08 and its count is 1056
# Now fetching data from 2022-11-09 to 2022-11-12
# Got demand data from date 2022-11-09 to 2022-11-12 and its count is 1056
# Now fetching data from 2022-11-13 to 2022-11-16
# Got demand data from date 2022-11-13 to 2022-11-16 and its count is 1056
# Now fetching data from 2022-11-17 to 2022-11-20
# Got demand data from date 2022-11-17 to 2022-11-20 and its count is 1056
# Now fetching data from 2022-11-21 to 2022-11-24
# Got demand data from date 2022-11-21 to 2022-11-24 and its count is 1056
# Now fetching data from 2022-11-25 to 2022-11-28
# Got demand data from date 2022-11-25 to 2022-11-28 and its count is 1056
# Now fetching data from 2022-11-29 to 2022-12-02
# Got demand data from date 2022-11-29 to 2022-12-02 and its count is 1056
# Now fetching data from 2022-12-03 to 2022-12-06
# Got demand data from date 2022-12-03 to 2022-12-06 and its count is 1056
# Now fetching data from 2022-12-07 to 2022-12-10
# Got demand data from date 2022-12-07 to 2022-12-10 and its count is 1056
# Now fetching data from 2022-12-11 to 2022-12-14
# Got demand data from date 2022-12-11 to 2022-12-14 and its count is 1056
# Now fetching data from 2022-12-15 to 2022-12-18
# Got demand data from date 2022-12-15 to 2022-12-18 and its count is 1056
# Now fetching data from 2022-12-19 to 2022-12-22
# Got demand data from date 2022-12-19 to 2022-12-22 and its count is 1056
# Now fetching data from 2022-12-23 to 2022-12-26
# Got demand data from date 2022-12-23 to 2022-12-26 and its count is 1056
# Now fetching data from 2022-12-27 to 2022-12-30
# Got demand data from date 2022-12-27 to 2022-12-30 and its count is 1056
# Now fetching data from 2022-12-31 to 2023-01-03
# Got demand data from date 2022-12-31 to 2023-01-03 and its count is 1056
# Now fetching data from 2023-01-04 to 2023-01-07
# Got demand data from date 2023-01-04 to 2023-01-07 and its count is 1056
# Now fetching data from 2023-01-08 to 2023-01-11
# Got demand data from date 2023-01-08 to 2023-01-11 and its count is 1056
# Now fetching data from 2023-01-12 to 2023-01-15
# Got demand data from date 2023-01-12 to 2023-01-15 and its count is 1056
# Now fetching data from 2023-01-16 to 2023-01-19
# Got demand data from date 2023-01-16 to 2023-01-19 and its count is 1056
# Now fetching data from 2023-01-20 to 2023-01-23
# Got demand data from date 2023-01-20 to 2023-01-23 and its count is 1056
# Now fetching data from 2023-01-24 to 2023-01-27
# Got demand data from date 2023-01-24 to 2023-01-27 and its count is 1056
# Now fetching data from 2023-01-28 to 2023-01-31
# Got demand data from date 2023-01-28 to 2023-01-31 and its count is 1056
# Now fetching data from 2023-02-01 to 2023-02-04
# Got demand data from date 2023-02-01 to 2023-02-04 and its count is 1056
# Now fetching data from 2023-02-05 to 2023-02-08
# Got demand data from date 2023-02-05 to 2023-02-08 and its count is 1056
# Now fetching data from 2023-02-09 to 2023-02-12
# Got demand data from date 2023-02-09 to 2023-02-12 and its count is 1056
# Now fetching data from 2023-02-13 to 2023-02-16
# Got demand data from date 2023-02-13 to 2023-02-16 and its count is 1056
# Now fetching data from 2023-02-17 to 2023-02-20
# Got demand data from date 2023-02-17 to 2023-02-20 and its count is 1056
# Now fetching data from 2023-02-21 to 2023-02-24
# Got demand data from date 2023-02-21 to 2023-02-24 and its count is 1056
# Now fetching data from 2023-02-25 to 2023-02-28
# Got demand data from date 2023-02-25 to 2023-02-28 and its count is 1056
# Now fetching data from 2023-03-01 to 2023-03-04
# Got demand data from date 2023-03-01 to 2023-03-04 and its count is 1056
# Now fetching data from 2023-03-05 to 2023-03-08
# Got demand data from date 2023-03-05 to 2023-03-08 and its count is 1056
# Now fetching data from 2023-03-09 to 2023-03-12
# Got demand data from date 2023-03-09 to 2023-03-12 and its count is 1056
# Now fetching data from 2023-03-13 to 2023-03-16
# Got demand data from date 2023-03-13 to 2023-03-16 and its count is 1056
# Now fetching data from 2023-03-17 to 2023-03-20
# Got demand data from date 2023-03-17 to 2023-03-20 and its count is 1056
# Now fetching data from 2023-03-21 to 2023-03-24
# Got demand data from date 2023-03-21 to 2023-03-24 and its count is 1056
# Now fetching data from 2023-03-25 to 2023-03-28
# Got demand data from date 2023-03-25 to 2023-03-28 and its count is 1056
# Now fetching data from 2023-03-29 to 2023-04-01
# Got demand data from date 2023-03-29 to 2023-04-01 and its count is 1056
# Now fetching data from 2023-04-02 to 2023-04-05
# Got demand data from date 2023-04-02 to 2023-04-05 and its count is 1056
# Now fetching data from 2023-04-06 to 2023-04-09
# Got demand data from date 2023-04-06 to 2023-04-09 and its count is 1056
# Now fetching data from 2023-04-10 to 2023-04-13
# Got demand data from date 2023-04-10 to 2023-04-13 and its count is 1056
# Now fetching data from 2023-04-14 to 2023-04-17
# Got demand data from date 2023-04-14 to 2023-04-17 and its count is 1056
# Now fetching data from 2023-04-18 to 2023-04-21
# Got demand data from date 2023-04-18 to 2023-04-21 and its count is 1056
# Now fetching data from 2023-04-22 to 2023-04-25
# Got demand data from date 2023-04-22 to 2023-04-25 and its count is 1056
# Now fetching data from 2023-04-26 to 2023-04-29
# Got demand data from date 2023-04-26 to 2023-04-29 and its count is 1056
# Now fetching data from 2023-04-30 to 2023-05-03
# Got demand data from date 2023-04-30 to 2023-05-03 and its count is 1056
# Now fetching data from 2023-05-04 to 2023-05-07
# Got demand data from date 2023-05-04 to 2023-05-07 and its count is 1056
# Now fetching data from 2023-05-08 to 2023-05-11
# Got demand data from date 2023-05-08 to 2023-05-11 and its count is 1056
# Now fetching data from 2023-05-12 to 2023-05-15
# Got demand data from date 2023-05-12 to 2023-05-15 and its count is 1056
# Now fetching data from 2023-05-16 to 2023-05-19
# Got demand data from date 2023-05-16 to 2023-05-19 and its count is 1056
# Now fetching data from 2023-05-20 to 2023-05-23
# Got demand data from date 2023-05-20 to 2023-05-23 and its count is 1056
# Now fetching data from 2023-05-24 to 2023-05-27
# Got demand data from date 2023-05-24 to 2023-05-27 and its count is 1056
# Now fetching data from 2023-05-28 to 2023-05-31
# Got demand data from date 2023-05-28 to 2023-05-31 and its count is 1056
# Now fetching data from 2023-06-01 to 2023-06-04
# Got demand data from date 2023-06-01 to 2023-06-04 and its count is 1056
# Now fetching data from 2023-06-05 to 2023-06-08
# Got demand data from date 2023-06-05 to 2023-06-08 and its count is 1056
# Now fetching data from 2023-06-09 to 2023-06-12
# Got demand data from date 2023-06-09 to 2023-06-12 and its count is 1056
# Now fetching data from 2023-06-13 to 2023-06-16
# Got demand data from date 2023-06-13 to 2023-06-16 and its count is 1056
# Now fetching data from 2023-06-17 to 2023-06-20
# Got demand data from date 2023-06-17 to 2023-06-20 and its count is 1056
# Now fetching data from 2023-06-21 to 2023-06-24
# Got demand data from date 2023-06-21 to 2023-06-24 and its count is 1056
# Now fetching data from 2023-06-25 to 2023-06-28
# Got demand data from date 2023-06-25 to 2023-06-28 and its count is 1056
# Now fetching data from 2023-06-29 to 2023-07-02
# Got demand data from date 2023-06-29 to 2023-07-02 and its count is 1056
# Now fetching data from 2023-07-03 to 2023-07-06
# Got demand data from date 2023-07-03 to 2023-07-06 and its count is 1056
# Now fetching data from 2023-07-07 to 2023-07-10
# Got demand data from date 2023-07-07 to 2023-07-10 and its count is 1056

# %%
region_data_dict_copy = dict(region_data_dict)

# %%
for k in region_data_dict_copy.keys():
    region_data_dict_copy[k]=pd.concat(region_data_dict_copy[k])

# %%
for k in region_data_dict_copy.keys():
    region_data_dict_copy[k].to_csv(f'/workspace/VoltWise/Lambda/Local_code/Data/New_data_csv/{k}-2023-07-10.csv',index=False)
    region_data_dict_copy[k].to_parquet(f'/workspace/VoltWise/Lambda/Local_code/Data/New_data_parquet/{k}.parquet')

# %%
ip= '/workspace/VoltWise/Lambda/Local_code/Data/Hourly/New_data_csv'
input_files = os.listdir(ip)
for file in input_files:
    input_path = os.path.join(ip, file)
    output_file = file.split('-')[0]
    df= pd.read_csv(input_path)
    df.drop(columns=['region'],inplace=True)
    print(output_file)
    df.to_csv(f'/workspace/VoltWise/Lambda/Local_code/Data/Hourly/New_data_csv/{output_file}.csv',index=False)
    df.to_parquet(f'/workspace/VoltWise/Lambda/Local_code/Data/Hourly/New_data_parquet/{output_file}.parquet')
# Out:
# CAL
# CAR
# CENT
# FLA
# MIDA
# MIDW
# NE
# NY
# SE
# SW
# TEX
